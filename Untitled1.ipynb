# %% [markdown]
# <a href="https://colab.research.google.com/github/compudiego/AdministracionCompudiego/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Punto:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def eje_x(self):
        return self.x

    def eje_y(self):
        return self.y

    def impresion(self):
        return "El punto se encuentra en x = " + str(self.x) + " y en y = " + str(self.y)

    def opuesto(self):
        return Punto(-self.x, -self.y)

# %%
punto_a = Punto(1, 2)
print(punto_a.impresion())

punto_b = punto_a.opuesto()
print(punto_b.impresion())
# Out:
# El punto se encuentra en x = 1 y en y = 2
# El punto se encuentra en x = -1 y en y = -2

# %%
class Linea:
  def __init__(self, punto1, punto2):
    self.p1 = punto1
    self.p2 = punto2

  def mueveDerecha(self, n):
    self.p1.x += n
    self.p2.x += n

  def mueveIzquierda(self, n):
    self.p1.x -= n
    self.p2.x -= n

  def mueveArriba(self, n):
    self.p1.y += n
    self.p2.y += n

  def mueveAbajo(self, n):
    self.p1.y -= n
    self.p2.y -= n

# %%
class Cancion:
  def __init__(self, autor, titulo):
    self.autor = autor
    self.titulo = titulo
  def get_autor(self):
    return self.autor
  def get_titulo(self):
    return self.titulo
  def set_titulo(self, titulo):
    self.titulo = titulo
  def set_autor(self, autor):
    self.autor = autor

# %%
class Persona:
  def __init__(self, nombre, apellido, dni):
    self.nombre = nombre
    self.apellido = apellido
    self.dni = dni
  def impresion(self):
    return "Nombre: " + self.nombre + "\nApellido: " + self.apellido

# %%
class Lugar:
  def __init__(self, ciudad, pais):
    self.ciudad = ciudad
    self.pais = pais

# %%
class Libro:
  def __init__(self, titulo, autor, ISBN, paginas, edicion, editorial, lugar, fechaEdicion):
    self.titulo = titulo
    self.autor = autor
    self.ISBN = ISBN
    self.paginas = paginas
    self.edicion = edicion
    self.editorial = editorial
    self.lugar = lugar
    self.fechaEdicion = fechaEdicion

  def get_titulo(self):
    return self.titulo

  def get_autor(self):
    return self.autor

  def get_ISBN(self):
    return self.ISBN

  def get_paginas(self):
    return self.paginas

  def get_edicion(self):
    return self.edicion

  def get_editorial(self):
    return self.editorial

  def get_lugar(self):
    return self.lugar

  def get_fechaEdicion(self):
    return self.fechaEdicion

  def mostrarInformacion(self):
    print("Título: " + self.titulo +"\nAutor: " + self.autor.impresion() + "\nISBN: " + self.ISBN + "\n"+self.lugar+ "\n"+self.fechaEdicion+ "\n"+self.paginas+ " páginas")

# %%
persona = Persona("Gabriel", "Garcia Marquez", "12345678")
lugar = Lugar("Buenos Aires", "Argentina")
libro = Libro("Cien años de soledad", persona,"9780060929794","784","Sudamericana",lugar,"Mayo 1967")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27511/1469614489.py in <cell line: 0>()
#       1 persona = Persona("Gabriel", "Garcia Marquez", "12345678")
#       2 lugar = Lugar("Buenos Aires", "Argentina")
# ----> 3 libro = Libro("Cien años de soledad", persona, "9780060929794", "784", "Tapa dura", "Primera", "Sudamericana", lugar, "Mayo 1967")
#
# TypeError: Libro.__init__() takes 9 positional arguments but 10 were given
